# %% [markdown]
# ## Exámen Final Mortalidad Materna

# %% [markdown]
# ## Introducción

# %% [markdown]
# ##Vamos a usar información contenida en una base de datos pública para analizar diferentes parámetros relacionados a la mortalidad materna para aplicar los conceptos vistos en la segunda semana de clases del Programa 30.01.

# %%
#El primer paso es importar las librerías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
tabla=pd.read_csv('mortalidad.csv')

# %%
tabla.head(6)
# Out:
#    Año de nacimiento  Mes de nacimiento Descripción del mes de nacimiento  \
# 0               1972                  6                             JUNIO
# 1               1967                  2                           FEBRERO
# 2               1973                  6                             JUNIO
# 3               1966                  1                             ENERO
# 4               1975                  0                   NO ESPECIFICADO
# 5               1975                  0                   NO ESPECIFICADO
#
#    Día de nacimiento  Genero Clave de la edad  Edad cumplida  Estado conyugal  \
# 0                 25       2                A             29                5
# 1                  1       2                A             35                5
# 2                 21       2                A             29                5
# 3                 23       2                A             36                5
# ...

# %%
tabla.tail(6)
# Out:
#        Año de nacimiento  Mes de nacimiento Descripción del mes de nacimiento  \
# 17226               1989                  8                            AGOSTO
# 17227               1995                 10                           OCTUBRE
# 17228               1971                 11                         NOVIEMBRE
# 17229               1994                 11                         NOVIEMBRE
# 17230               1976                  5                              MAYO
# 17231               1990                  8                            AGOSTO
#
#        Día de nacimiento  Genero Clave de la edad  Edad cumplida  \
# 17226                  2       2                A             27
# 17227                  6       2                A             20
# 17228                 14       2                A             45
# 17229                 26       2                A             21
# 17230                 12       2                A             39
# ...

# %% [markdown]
# #En las dos tablas anteriores, podemos ver los primeros seis elementos de la base de datos y los últimos seis elementos, respectivamente.

# %% [markdown]
# ###Aquí quiero saber los nombres de los encabezados

# %%
list(tabla.columns.values)
# Out:
# ['Año de nacimiento',
#  'Mes de nacimiento',
#  'Descripción del mes de nacimiento',
#  'Día de nacimiento',
#  'Genero',
#  'Clave de la edad',
#  'Edad cumplida',
#  'Estado conyugal',
#  'Descripción del estado conyugal',
#  'Entidad de residencia',
#  'Descripción de entidad de residencia',
#  'Municipio de residencia',
#  'Descripción del municipio de residencia',
#  'Localidad de residencia',
#  'Descripión de la localidad de residencia',
#  'Tamaño de localidad',
#  'Descripción del tamaño de localidad',
#  'Ocupación habitual',
#  'Descripción de la ocupación habitual',
#  'Escolaridad',
#  'Descripción de la escolaridad',
#  'Derechiahabiencia',
#  'Descrición de la derechiahabiencia',
#  'Entidad de ocurrencia',
#  'Descripción de la entidad de ocurrencia',
#  'Municipio de ocurrencia',
#  'Descrición del municipio de ocurrencia',
#  'Localidad de ocurrencia',
#  'Descrición de la localidad de ocurrencia',
#  'Sitio donde ocurrio la defunción',
# ...

# %% [markdown]
# ###Aquí quiero mostrar un DataFrame que contenga: Edad cumplida, Descripción del estado conyugal, Tamaño de la localidad, Localidad de ocurrencia, Descripcióm de la localidad de ocurrencia.

# %% [markdown]
# ###Aquí quiero mostrar el valor promedio de la edad cumplida de las mujeres

# %%
tabla['Edad cumplida'].describe()
# Out:
# count    17232.000000
# mean        29.765727
# std         36.916010
# min         11.000000
# 25%         22.000000
# 50%         28.000000
# 75%         34.000000
# max        998.000000
# Name: Edad cumplida, dtype: float64

# %% [markdown]
# ###Aquí pudimos ver los datos estadísticos para la columna Edad cumplida, que nos va ayudar a entender a la población contenida en la tabla.

# %% [markdown]
# ###Aquí quiero mostrar cuántas edades diferentes tenían las madres cuando fallecieron:

# %%
tabla=['Edad cumplida'].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-29de62c600b9> in <module>()
# ----> 1 tabla=['Edad cumplida'].unique()
#
# AttributeError: 'list' object has no attribute 'unique'

# %% [markdown]
# ###En esta sección, quiero imprimir los valores de los años de defunción para revisar si los datos están correctos o son lógicos.

# %%
for v in tabla['Año de la defunción']:
    print (v)
# Out:
# 2002
# 2002
# 2002
# 2002
# 2005
# 2005
# 2005
# 2005
# 2002
# 2002
# 2003
# 2002
# 2008
# 2002
# 2005
# 2005
# 2005
# 2013
# 2013
# 2013
# 2012
# 2013
# 2009
# 2009
# 2010
# 2009
# 2011
# 2011
# 2011
# 2011
# 2012
# 2011
# 2011
# 2010
# 2011
# 2012
# 2013
# 2013
# 2013
# 2003
# 2003
# 2003
# 2003
# 2003
# 2003
# 2003
# 2003
# 2013
# 2003
# 2005
# 2005
# 2005
# 2004
# 2004
# 2003
# 2003
# 2004
# 2004
# 2004
# 2004
# 2004
# 2003
# 2003
# 2003
# 2003
# 2005
# 2005
# 2006
# 2002
# 2002
# 2002
# 2002
# 2006
# 2005
# 2005
# 2002
# 2002
# 2002
# 2005
# 2005
# 2005
# 2005
# 2005
# 2005
# 2005
# 2005
# 2005
# 2005
# 2003
# 2002
# 2003
# 2003
# 2002
# 2002
# 2002
# 2002
# 2006
# 2007
# 2007
# 2006
# 2006
# 2006
# 2008
# 2008
# 2006
# 2007
# 2008
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2013
# 2013
# 2004
# 2003
# 2002
# 2006
# 2003
# 2003
# 2003
# 2003
# 2003
# 2003
# 2004
# 2003
# 2003
# 2003
# 2003
# 2003
# 2003
# 2003
# 2003
# 2003
# ...

# %% [markdown]
# ###De los años desplegados, podemos ver que muestran años recientes de las últimas dos décadas y son válidos.

# %% [markdown]
# ###Ahora quiero saber cuántos tipos de escolaridad existen en la base de datos:

# %%
tabla['Escolaridad'].value_counts()
# Out:
# 5     4138
# 3     3360
# 2     2688
# 6     2142
# 1     1506
# 7     1492
# 4      920
# 0      636
# 11     326
# 10      22
# 12       2
# Name: Escolaridad, dtype: int64

# %% [markdown]
# ###Pudimos ver que tenemos 11 tipos diferentes de escolaridades.

# %% [markdown]
# ###Quiero saber cuál es la entidad con mayor número de defunciones

# %%
tabla['Entidad de registro'].value_counts()
# Out:
# 15    1914
# 9     1884
# 30    1217
# 7     1163
# 21    1027
# 12     938
# 14     854
# 20     845
# 11     694
# 8      656
# 16     624
# 28     413
# 19     408
# 13     398
# 27     391
# 24     384
# 2      373
# 26     306
# 5      302
# 31     298
# 25     294
# 22     262
# 10     258
# 17     238
# 32     199
# 23     178
# 29     165
# 18     163
# 1      150
# 4      124
# 3       69
# 6       43
# Name: Entidad de registro, dtype: int64

# %% [markdown]
# ###Los datos anteriores no me sirven, pues necesito desplegar la Descrición de la entidad de registro:

# %%
tabla['Descrición de la entidad de registro'].value_counts()
# Out:
# México                             1914
# Distrito Federal                   1884
# Veracruz de Ignacio de la Llave    1217
# Chiapas                            1163
# Puebla                             1027
# Guerrero                            938
# Jalisco                             854
# Oaxaca                              845
# Guanajuato                          694
# Chihuahua                           656
# Michoacán de Ocampo                 624
# Tamaulipas                          413
# Nuevo León                          408
# Hidalgo                             398
# Tabasco                             391
# San Luis Potosí                     384
# Baja California                     373
# Sonora                              306
# Coahuila de Zaragoza                302
# Yucatán                             298
# Sinaloa                             294
# Durango                             258
# Morelos                             238
# ...

# %% [markdown]
# ###Ahora sí pudimos ver los nombres de las Entidades con sus números de defunciones y además las ordenamos de mayor a menor para darnos una mejor idea de las cifras.

# %% [markdown]
# ### Ahora quiero imprimir dos DataFrames
